# %% [markdown]
# <a href="https://colab.research.google.com/github/waynelu312-ship-it/jupyter-exploration/blob/main/new.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# My first markdown cell in jupyter!

# %%
print("Hello World")
# Out:
# Hello World
